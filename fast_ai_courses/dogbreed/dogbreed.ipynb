# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
PATH = "data/"
sz=224
arch=resnext101_64
bs=58

# %%
label_csv = f'{PATH}labels.csv'
n = len(list(open(label_csv)))-1 # num of images that we have
val_idxs = get_cv_idxs(n) # (get cross validation indexes) return random list of indexex as 20% of 'n'

# %%
val_idxs.shape, n
# Out:
# ((2044,), 10222)

# %%
label_df = pd.read_csv(label_csv)
label_df.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
label_df.pivot_table(index='breed', aggfunc=len).sort_values('id', ascending=False)
# Out:
#                                  id
# breed
# scottish_deerhound              126
# maltese_dog                     117
# afghan_hound                    116
# entlebucher                     115
# bernese_mountain_dog            114
# shih-tzu                        112
# great_pyrenees                  111
# pomeranian                      111
# basenji                         110
# samoyed                         109
# airedale                        107
# tibetan_terrier                 107
# leonberg                        106
# cairn                           106
# beagle                          105
# japanese_spaniel                105
# australian_terrier              102
# blenheim_spaniel                102
# miniature_pinscher              102
# irish_wolfhound                 101
# lakeland_terrier                 99
# saluki                           99
# papillon                         96
# whippet                          95
# siberian_husky                   95
# norwegian_elkhound               95
# pug                              94
# chow                             93
# italian_greyhound                92
# pembroke                         92
# ...                             ...
# german_short-haired_pointer      75
# boxer                            75
# bull_mastiff                     75
# borzoi                           75
# pekinese                         75
# cocker_spaniel                   74
# american_staffordshire_terrier   74
# doberman                         74
# brittany_spaniel                 73
# malinois                         73
# standard_schnauzer               72
# flat-coated_retriever            72
# redbone                          72
# border_collie                    72
# curly-coated_retriever           72
# kuvasz                           71
# chihuahua                        71
# soft-coated_wheaten_terrier      71
# french_bulldog                   70
# vizsla                           70
# tibetan_mastiff                  69
# german_shepherd                  69
# giant_schnauzer                  69
# walker_hound                     69
# otterhound                       69
# golden_retriever                 67
# brabancon_griffon                67
# komondor                         67
# briard                           66
# eskimo_dog                       66
#
# [120 rows x 1 columns]

# %%
tfms
# Out:
# ([<fastai.transforms.RandomScale object at 0x7fb56c6b1748>, <fastai.transforms.RandomRotate object at 0x7fb56df79438>, <fastai.transforms.RandomLighting object at 0x7fb56df794a8>, <fastai.transforms.RandomFlip object at 0x7fb56df794e0>, <fastai.transforms.RandomCrop object at 0x7fb56c6b17b8>, <fastai.transforms.Normalize object at 0x7fb56c6b15c0>, <fastai.transforms.ChannelOrder object at 0x7fb56c6b17f0>],
#  [<fastai.transforms.Scale object at 0x7fb56c6b1668>, <fastai.transforms.CenterCrop object at 0x7fb56c6b16d8>, <fastai.transforms.Normalize object at 0x7fb56c6b15c0>, <fastai.transforms.ChannelOrder object at 0x7fb56c6b1710>])

# %%
tfms = tfms_from_model(arch, sz, aug_tfms=transforms_side_on, max_zoom=1.1)
data = ImageClassifierData.from_csv(PATH, 'train', f'{PATH}labels.csv', test_name='test',
                                    val_idxs=val_idxs, suffix='.jpg', tfms=tfms, bs=bs)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-51d223b57206> in <module>()
#       1 tfms = tfms_from_model(arch, sz, aug_tfms=transforms_side_on, max_zoom=1.1)
#       2 data = ImageClassifierData.from_csv(PATH, 'train', f'{PATH}labels.csv', test_name='test',
# ----> 3                                     val_idxs=val_idxs, suffix='.jpg', tfms=tfms, bs=bs)
#
# ~/exit-fastai/dogbreed/fastai/dataset.py in from_csv(cls, path, folder, csv_fname, bs, tfms, val_idxs, suffix, test_name, continuous, skip_header, num_workers)
#     457         fnames,y,classes = csv_source(folder, csv_fname, skip_header, suffix, continuous=continuous)
#     458         return cls.from_names_and_array(path, fnames, y, classes, val_idxs, test_name,
# --> 459                 num_workers=num_workers, suffix=suffix, tfms=tfms, bs=bs, continuous=continuous)
#     460
#     461     @classmethod
#
# ~/exit-fastai/dogbreed/fastai/dataset.py in from_names_and_array(cls, path, fnames, y, classes, val_idxs, test_name, num_workers, suffix, tfms, bs, continuous)
#     470             f = FilesIndexArrayDataset if len(trn_y.shape)==1 else FilesNhotArrayDataset
#     471         datasets = cls.get_ds(f, (trn_fnames,trn_y), (val_fnames,val_y), tfms,
# --> 472                                path=path, test=test_fnames)
#     473         return cls(path, datasets, bs, num_workers, classes=classes)
#     474
#
# ~/exit-fastai/dogbreed/fastai/dataset.py in get_ds(fn, trn, val, tfms, test, **kwargs)
#     372                 test = test[0]
#     373             else:
# --> 374                 test_lbls = np.zeros((len(test),trn[1].shape[1]))
#     375             res += [
#     376                 fn(test, test_lbls, tfms[1], **kwargs), # test
#
# IndexError: tuple index out of range
